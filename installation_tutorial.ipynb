# %% [markdown]
# # ViMOP installation
#
# This tutorial describes multiple ways how to install ViMOP on your Linux or MacOS system.

# %% [markdown]
# # Prerequisites
#
# ViMOP uses epi2me, nextflow and docker. All of these dependencies can be installed with and without the usage of the command line depending on the user's preference.

# %% [markdown]
# ## Installation with graphical user interface (EPI2ME)
#
# To use ViMOP in the graphical user interface you need to install Oxford Nanopore's EPI2ME Desktop application. If you only want to use it as command line tool you can skip this step.

# %% [markdown]
# ### 1. Install Docker Desktop
# Download the Docker Desktop installer according to your operating system on the bottom of this [Docker docs page](https://docs.docker.com/desktop/)

# %% [markdown]
# ### 2. Install EPI2ME
# Download the installer according to your operating system from the [EPI2ME website](https://epi2me.nanoporetech.com/downloads/). At the time of this tutorial the most recent version of EPI2ME Desktop is version 5.2.5.

# %% [markdown]
# ### Install Nextflow
# If nextflow is missing the System setup of EPI2ME under Settings->Local will look like this.
#
# [image]
#
# Click the nextflow icon and allow EPI2ME to install nextflow in your system.

# %% [markdown]
# # Installation using command line

# %% [markdown]
# # Quick start
#
# If you have nextflow and docker installed in your system
